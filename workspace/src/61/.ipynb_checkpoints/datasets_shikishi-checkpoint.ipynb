# %%
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
df = pd.read_csv('../data/Pokemon.csv', sep=',')
print(df[['Number', 'Type1', 'Type2']])
# Out:
#      Number     Type1     Type2
# 0         1     Grass    Poison
# 1         2     Grass    Poison
# 2         3     Grass    Poison
# 3         3     Grass    Poison
# 4         4      Fire       NaN
# 5         5      Fire       NaN
# 6         6      Fire    Flying
# 7         6      Fire    Dragon
# 8         6      Fire    Flying
# 9         7     Water       NaN
# 10        8     Water       NaN
# 11        9     Water       NaN
# 12        9     Water       NaN
# 13       10       Bug       NaN
# 14       11       Bug       NaN
# 15       12       Bug    Flying
# 16       13       Bug    Poison
# 17       14       Bug    Poison
# 18       15       Bug    Poison
# 19       15       Bug    Poison
# 20       16    Normal    Flying
# 21       17    Normal    Flying
# 22       18    Normal    Flying
# 23       18    Normal    Flying
# 24       19    Normal       NaN
# 25       20    Normal       NaN
# 26       21    Normal    Flying
# 27       22    Normal    Flying
# 28       23    Poison       NaN
# 29       24    Poison       NaN
# ..      ...       ...       ...
# 864     781     Ghost     Grass
# 865     782    Dragon       NaN
# 866     783    Dragon  Fighting
# 867     784    Dragon  Fighting
# 868     785  Electric     Fairy
# 869     786   Psychic     Fairy
# 870     787     Grass     Fairy
# 871     788     Water     Fairy
# 872     789   Psychic       NaN
# 873     790   Psychic       NaN
# 874     791   Psychic     Steel
# 875     792   Psychic     Ghost
# 876     793      Rock    Poison
# 877     794       Bug  Fighting
# 878     795       Bug  Fighting
# 879     796  Electric       NaN
# 880     797     Steel    Flying
# 881     798     Grass     Steel
# 882     799      Dark    Dragon
# 883     800   Psychic       NaN
# 884     800   Psychic     Steel
# 885     800   Psychic     Ghost
# 886     800   Psychic    Dragon
# 887     801     Steel     Fairy
# 888     802  Fighting     Ghost
# 889     803    Poison       NaN
# 890     804    Poison    Dragon
# 891     805      Rock     Steel
# 892     806      Fire     Ghost
# 893     807  Electric       NaN
#
# [894 rows x 3 columns]

# %%
df2 = df.drop_duplicates(subset='Number')
df2.reset_index(inplace=True, drop=True)
df2 = df2[['Number', 'Type1', 'Type2']]
df2 = df2.replace({"Normal": 0, 
                   "Fire": 1, 
                   "Water": 2, 
                   "Electric": 3, 
                   "Grass": 4, 
                   "Ice": 5, 
                   "Fighting": 6, 
                   "Poison": 7, 
                   "Ground": 8, 
                   "Flying": 9, 
                   "Psychic": 10, 
                   "Bug": 11, 
                   "Rock": 12, 
                   "Ghost": 13, 
                   "Dragon": 14, 
                   "Dark": 15, 
                   "Steel": 16, 
                   "Fairy": 17})
ind = df2[df2['Type2'].isnull()]['Type2'].index
df2.iloc[ind, 2] = df2.iloc[ind, 1]
print(df2)
# Out:
#      Number  Type1  Type2
# 0         1      4    7.0
# 1         2      4    7.0
# 2         3      4    7.0
# 3         4      1    1.0
# 4         5      1    1.0
# 5         6      1    9.0
# 6         7      2    2.0
# 7         8      2    2.0
# 8         9      2    2.0
# 9        10     11   11.0
# 10       11     11   11.0
# 11       12     11    9.0
# 12       13     11    7.0
# 13       14     11    7.0
# 14       15     11    7.0
# 15       16      0    9.0
# 16       17      0    9.0
# 17       18      0    9.0
# 18       19      0    0.0
# 19       20      0    0.0
# 20       21      0    9.0
# 21       22      0    9.0
# 22       23      7    7.0
# 23       24      7    7.0
# 24       25      3    3.0
# 25       26      3    3.0
# 26       27      8    8.0
# 27       28      8    8.0
# 28       29      7    7.0
# 29       30      7    7.0
# ..      ...    ...    ...
# 777     778     13   17.0
# 778     779      2   10.0
# 779     780      0   14.0
# 780     781     13    4.0
# 781     782     14   14.0
# 782     783     14    6.0
# 783     784     14    6.0
# 784     785      3   17.0
# 785     786     10   17.0
# 786     787      4   17.0
# 787     788      2   17.0
# 788     789     10   10.0
# 789     790     10   10.0
# 790     791     10   16.0
# 791     792     10   13.0
# 792     793     12    7.0
# 793     794     11    6.0
# 794     795     11    6.0
# 795     796      3    3.0
# 796     797     16    9.0
# 797     798      4   16.0
# 798     799     15   14.0
# 799     800     10   10.0
# 800     801     16   17.0
# 801     802      6   13.0
# 802     803      7    7.0
# 803     804      7   14.0
# 804     805     12   16.0
# 805     806      1   13.0
# 806     807      3    3.0
#
# [807 rows x 3 columns]

# %%
# %matplotlib inline
im = Image.open('../data/images/0008.png')
im_list = np.asarray(im)
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
images_path = glob.glob('../data/images/*')
images_path.sort()
image_image = []
for i in images_path:
    im = Image.open(i)
    image_image.append(np.asarray(im))
plt.imshow(image_image[800])
